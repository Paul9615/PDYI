# %% [markdown]
# # 모듈
# 코드 관리를 위한 논리적 단위\
# 일반적으로 하나의 .py 파일이 하나의 module\
# module 內 함수, 클래스, 변수들의 정의가능, 실행코드 포함
#
# ### 패키지
# 관련된 modue의 집합\
# 패키지는 디렉토리 단위로 관리

# %%
# thrid party
# !pip list
help('pandas')
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# alembic                            1.4.1
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.8.3
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# ...

# %%
import os # module import
import numpy as np # alias 
from scipy import stats # module, class or func. name

# %%
# application module
import sys 
# sys.path -> physical location of module

# %% [markdown]
# # 사용자 정의 모듈

# %%
# user definition module
import calla 
print(calla.adda(43,56))

from calculation import cla
print(cla.addd(1,2))
# Out:
# 99
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-d1ad9942dfde> in <module>
#       3 print(calla.adda(43,56))
#       4
# ----> 5 from calculation import cla
#       6 print(cla.addd(1,2))
#
# ImportError: cannot import name 'cla' from 'calculation' (C:\Users\rudal\OneDrive\바탕 화면\공빅데\PDYI\day4\calculation.py)
